# %% [markdown]
# ##目標：看誰會過，誰不會過

# %%
# %pylab inline
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
adv_data=pd.read_excel('adv_data.xlsx')
adv_data.head()
# Out:
#       系級         學號   姓名  9/24  10/01  10/08  10/15  10/22  10/29  11/26  \
# 序號   NaN        NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   中文一乙  103101086  柴貞全     5      0      0      0      0      0      0
# 2   財政三甲  101205089  蔡千舜    20      3     20      5     15     10      0
# 3   經濟四甲  100208047  黃柏孝    10      0      0      0      0      0      0
# 4    應數一  103701006  暴琇孝    10      0     13      0     15      0      3
#
#      ...    12/16  上台      平時  期中2  期中1  期中總分  期末     方案一   方案二    總分試算
# 序號   ...      NaN NaN     NaN  NaN  NaN   NaN NaN     NaN   NaN     NaN
# 1    ...        0   1   4.125    0   10    10   0   7.125   4.0   7.125
# 2    ...       20   4  20.000   15   34    49  33  51.200  39.4  51.200
# 3    ...       20   0   6.250    0    5     5   0   7.750   2.0   7.750
# 4    ...       20   2  19.250    0   67    67  22  50.350  40.0  50.350
#
# [5 rows x 26 columns]

# %%
adv_data.columns
# Out:
# Index([u'系級', u'學號', u'姓名', u'9/24', u'10/01', u'10/08', u'10/15', u'10/22', u'10/29', u'11/26', u'12/03', u'12/10', u'10/07', u'10/16', u'10/28', u'11/27', u'12/16', u'上台', u'平時', u'期中2', u'期中1', u'期中總分', u'期末', u'方案一', u'方案二', u'總分試算'], dtype='object')

# %%
adv_data[u'最後成績']=adv_data[u'總分試算']+20

# %%
adv_data.head()
# Out:
#       系級         學號   姓名  9/24  10/01  10/08  10/15  10/22  10/29  11/26  \
# 序號   NaN        NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   中文一乙  103101086  柴貞全     5      0      0      0      0      0      0
# 2   財政三甲  101205089  蔡千舜    20      3     20      5     15     10      0
# 3   經濟四甲  100208047  黃柏孝    10      0      0      0      0      0      0
# 4    應數一  103701006  暴琇孝    10      0     13      0     15      0      3
#
#      ...    上台      平時  期中2  期中1  期中總分  期末     方案一   方案二    總分試算    最後成績
# 序號   ...   NaN     NaN  NaN  NaN   NaN NaN     NaN   NaN     NaN     NaN
# 1    ...     1   4.125    0   10    10   0   7.125   4.0   7.125  27.125
# 2    ...     4  20.000   15   34    49  33  51.200  39.4  51.200  71.200
# 3    ...     0   6.250    0    5     5   0   7.750   2.0   7.750  27.750
# 4    ...     2  19.250    0   67    67  22  50.350  40.0  50.350  70.350
#
# [5 rows x 27 columns]

# %%
len(adv_data[adv_data[u'最後成績']>=60])
# Out:
# 42

# %%
adv_data[u'過']=pd.DataFrame(adv_data[u'最後成績']>=60)

# %%
adv_data.head()
# Out:
#       系級         學號   姓名  9/24  10/01  10/08  10/15  10/22  10/29  11/26  \
# 序號   NaN        NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   中文一乙  103101086  柴貞全     5      0      0      0      0      0      0
# 2   財政三甲  101205089  蔡千舜    20      3     20      5     15     10      0
# 3   經濟四甲  100208047  黃柏孝    10      0      0      0      0      0      0
# 4    應數一  103701006  暴琇孝    10      0     13      0     15      0      3
#
#     ...        平時  期中2  期中1  期中總分  期末     方案一   方案二    總分試算    最後成績      過
# 序號  ...       NaN  NaN  NaN   NaN NaN     NaN   NaN     NaN     NaN  False
# 1   ...     4.125    0   10    10   0   7.125   4.0   7.125  27.125  False
# 2   ...    20.000   15   34    49  33  51.200  39.4  51.200  71.200   True
# 3   ...     6.250    0    5     5   0   7.750   2.0   7.750  27.750  False
# 4   ...    19.250    0   67    67  22  50.350  40.0  50.350  70.350   True
#
# [5 rows x 28 columns]

# %%
adv_data[u'數']=adv_data[u'過'].str.contains('True')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-6e020a5f4b57> in <module>()
# ----> 1 adv_data[u'數']=adv_data[u'過'].str.contains('True').resample('D')
#
# /Users/annie/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base)
#    3003                               fill_method=fill_method, convention=convention,
#    3004                               limit=limit, base=base)
# -> 3005         return sampler.resample(self).__finalize__(self)
#    3006
#    3007     def first(self, offset):
#
# /Users/annie/anaconda/lib/python2.7/site-packages/pandas/tseries/resample.pyc in resample(self, obj)
#     103             return self.obj
#     104         else:  # pragma: no cover
# ...

# %%
adv_data.head()
# Out:
#       系級         學號   姓名  9/24  10/01  10/08  10/15  10/22  10/29  11/26 ...  \
# 序號   NaN        NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN ...
# 1   中文一乙  103101086  柴貞全     5      0      0      0      0      0      0 ...
# 2   財政三甲  101205089  蔡千舜    20      3     20      5     15     10      0 ...
# 3   經濟四甲  100208047  黃柏孝    10      0      0      0      0      0      0 ...
# 4    應數一  103701006  暴琇孝    10      0     13      0     15      0      3 ...
#
#     期中2  期中1  期中總分  期末     方案一   方案二    總分試算    最後成績      過   數
# 序號  NaN  NaN   NaN NaN     NaN   NaN     NaN     NaN  False NaN
# 1     0   10    10   0   7.125   4.0   7.125  27.125  False NaN
# 2    15   34    49  33  51.200  39.4  51.200  71.200   True NaN
# 3     0    5     5   0   7.750   2.0   7.750  27.750  False NaN
# 4     0   67    67  22  50.350  40.0  50.350  70.350   True NaN
#
# [5 rows x 29 columns]

# %%
adv_data[u'數']=adv_data[u'過'].replace({False:0})

# %% [markdown]
# ###<b style="color:#0000FF">還在試著處理把它用0,1表示</b>

# %%
adv_data.head()
# Out:
#       系級         學號   姓名  9/24  10/01  10/08  10/15  10/22  10/29  11/26  \
# 序號   NaN        NaN  NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   中文一乙  103101086  柴貞全     5      0      0      0      0      0      0
# 2   財政三甲  101205089  蔡千舜    20      3     20      5     15     10      0
# 3   經濟四甲  100208047  黃柏孝    10      0      0      0      0      0      0
# 4    應數一  103701006  暴琇孝    10      0     13      0     15      0      3
#
#     ...    期中2  期中1  期中總分  期末     方案一   方案二    總分試算    最後成績      過      數
# 序號  ...    NaN  NaN   NaN NaN     NaN   NaN     NaN     NaN  False  False
# 1   ...      0   10    10   0   7.125   4.0   7.125  27.125  False  False
# 2   ...     15   34    49  33  51.200  39.4  51.200  71.200   True   True
# 3   ...      0    5     5   0   7.750   2.0   7.750  27.750  False  False
# 4   ...      0   67    67  22  50.350  40.0  50.350  70.350   True   True
#
# [5 rows x 29 columns]

# %%
adv_data.to_excel('adv_data.xlsx')
